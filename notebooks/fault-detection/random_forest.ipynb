# %% [markdown]
# # PV Fault Detection Using Random Forest
#
# This notebook implements a **multi-class** fault detection system for **photovoltaic (PV) systems** using electrical measurements.
#
# The objective is to classify different fault types using a Random Forest classifier and evaluate its performance using multiple metrics.

# %%
# !git clone https://github.com/clayton-h-costa/pv_fault_dataset.git
# Out:
# fatal: destination path 'pv_fault_dataset' already exists and is not an empty directory.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from scipy.io import loadmat
warnings.filterwarnings('ignore')

# Set ggplot style
plt.style.use('ggplot')

# ML and Deep Learning
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate, RandomizedSearchCV
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    balanced_accuracy_score,
    precision_recall_fscore_support,
    cohen_kappa_score,
    log_loss,
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve,
    auc
)
from sklearn.ensemble import RandomForestClassifier
import os
import shap
import joblib

# %% [markdown]
# ## Dataset Description
#
# The dataset contains electrical and ambient measurements from a PV system:
#
# - `vdc1`, `vdc2` — DC voltages
# - `idc1`, `idc2` — DC currents
# - `irradiance` — Solar irradiance
# - `temperature` — Panel temperature
# - `fault_label` — Fault category
#
# Fault classes:
# - Normal Operation
# - Short-Circuit
# - Open Circuit
# - Shadowing

# %%
# Load the dataset
elec_data = loadmat("pv_fault_dataset/dataset_elec.mat")
amb_data  = loadmat("pv_fault_dataset/dataset_amb.mat")

# %%
# Extract variables
vdc1 = elec_data['vdc1'].flatten()
vdc2 = elec_data['vdc2'].flatten()
idc1 = elec_data['idc1'].flatten()
idc2 = elec_data['idc2'].flatten()

irr = amb_data['irr'].flatten()
pvt = amb_data['pvt'].flatten()
f_nv = amb_data['f_nv'].flatten()

# Create a DataFrame for easier analysis
df = pd.DataFrame({
    'vdc1': vdc1,
    'vdc2': vdc2,
    'idc1': idc1,
    'idc2': idc2,
    'irradiance': irr,
    'temperature': pvt,
    'fault_label': f_nv
})

df = df[df['fault_label'] != 2].copy()

# %%
# View the features
df.head()
# Out:
#      vdc1    vdc2    idc1    idc2  irradiance  temperature  fault_label
# 0  0.7143  0.5550  0.0608  0.0073      1.3729       2.3816            0
# 1  0.6944  0.5427  0.0615  0.0064      1.3604       2.3816            0
# 2  0.7110  0.5583  0.0646  0.0067      1.5118       2.3883            0
# 3  0.6991  0.5465  0.0628  0.0067      1.5534       2.3920            0
# 4  0.7035  0.5553  0.0606  0.0076      1.4355       2.3920            0

# %%
# Total samples
print("Total samples:", len(df))
# Out:
# Total samples: 1363427

# %%
# Label value counts
df['fault_label'].value_counts()
# Out:
# fault_label
# 0    1162931
# 4     188473
# 3       6024
# 1       5999
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preprocessing
#
# To improve model performance, additional domain-based engineered features are created:
#
# - Power per string
# - Total power
# - Voltage ratio
# - Current ratio
#
# Electrical power for each PV string is computed using the fundamental relation:
#
# $$
# P = V \times I
# $$
#
# where:
#
# - $P$ - Power (Watts)
# - $V$ - Voltage (Volts)
# - $I$ - Current (Amperes)
#
# Using this relation, the following features were derived:
# - String 1 Power: $P_1 = V_{dc1} \times I_{dc1}$
# - String 2 Power: $P_2 = V_{dc2} \times I_{dc2}$
# - Total Power: $P_{total} = P_1 + P_2$
#
#
# These features help capture electrical imbalances caused by faults.
#
# Furthermore, class labels were mapped to the respective fault class from the dataset.

# %%
# Add calculated columns
df['power_string1'] = df['vdc1'] * df['idc1']
df['power_string2'] = df['vdc2'] * df['idc2']
df['total_power'] = df['power_string1'] + df['power_string2']
df['voltage_ratio'] = df['vdc1'] / df['vdc2']
df['current_ratio'] = df['idc1'] / df['idc2']

print(f"Dataset shape: {df.shape}")
print(f"Number of samples: {len(df)}")

# Create fault name mapping
fault_names = {
    0: 'Normal Operation',
    1: 'Short-Circuit',
    3: 'Open Circuit',
    4: 'Shadowing'
}

# Add fault name column
df['fault_label'] = df['fault_label'].map(fault_names)
# Out:
# Dataset shape: (1363427, 12)
# Number of samples: 1363427

# %%
# View preprocessed dataset
df.head()
# Out:
#      vdc1    vdc2    idc1    idc2  irradiance  temperature       fault_label  \
# 0  0.7143  0.5550  0.0608  0.0073      1.3729       2.3816  Normal Operation
# 1  0.6944  0.5427  0.0615  0.0064      1.3604       2.3816  Normal Operation
# 2  0.7110  0.5583  0.0646  0.0067      1.5118       2.3883  Normal Operation
# 3  0.6991  0.5465  0.0628  0.0067      1.5534       2.3920  Normal Operation
# 4  0.7035  0.5553  0.0606  0.0076      1.4355       2.3920  Normal Operation
#
#    power_string1  power_string2  total_power  voltage_ratio  current_ratio
# 0       0.043429       0.004052     0.047481       1.287027       8.328767
# 1       0.042706       0.003473     0.046179       1.279528       9.609375
# 2       0.045931       0.003741     0.049671       1.273509       9.641791
# 3       0.043903       0.003662     0.047565       1.279231       9.373134
# 4       0.042632       0.004220     0.046852       1.266883       7.973684

# %%
# Seperate data
X = df.drop(['fault_label'], axis=1).values
y = df['fault_label'].values

print("X Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# X Shape: (1363427, 11)
# y Shape: (1363427,)

# %%
feature_names = df.drop(['fault_label'], axis=1).columns.tolist()
feature_names
# Out:
# ['vdc1',
#  'vdc2',
#  'idc1',
#  'idc2',
#  'irradiance',
#  'temperature',
#  'power_string1',
#  'power_string2',
#  'total_power',
#  'voltage_ratio',
#  'current_ratio']

# %% [markdown]
# ## Train-Test Splitting
#
# The dataset is split into 80% training and 20% testing data using stratified sampling to preserve class distribution.

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Show the shapes
print("X train shape:", X_train.shape)
print("X test shape:", X_test.shape)
print("y train shape:", y_train.shape)
print("y test shape:", y_test.shape)
# Out:
# X train shape: (1090741, 11)
# X test shape: (272686, 11)
# y train shape: (1090741,)
# y test shape: (272686,)

# %%
# View total samples
print("Training set:", len(X_train),"samples")
print("Testing set:", len(X_test),"samples")
# Out:
# Training set: 1090741 samples
# Testing set: 272686 samples

# %% [markdown]
# ## Class Imbalance Handling
#
# The dataset contains class imbalance, where some fault categories contain significantly fewer samples than others.
#
# To prevent the model from being biased toward the majority class, class weights are computed and applied during training.
#
# The weight for each class is defined as:
#
# $$
# w_i = \frac{N}{K \cdot n_i}
# $$
#
# where:
#
# - $N$ - Total number of samples
# - $K$ - Number of classes
# - $n_i$ - Number of samples in class $i$
#
# Hence, this ensures that misclassification of minority classes is penalized more heavily, improving balanced performance across all fault categories.

# %%
classes = np.unique(y_train)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
class_weights = dict(zip(classes, weights))
print("Class weights:", class_weights)
# Out:
# Class weights: {'Normal Operation': np.float64(0.2931015301866836), 'Open Circuit': np.float64(56.585443037974684), 'Shadowing': np.float64(1.808509474131013), 'Short-Circuit': np.float64(56.82126484684309)}

# %% [markdown]
# ## Model Training – Random Forest
#
# A Random Forest classifier is used due to its robustness, ability to handle non-linearity, and resistance to overfitting.
#
# Class weights are applied to address class imbalance.

# %%
rf = RandomForestClassifier(
    random_state=42,
    n_jobs=-1,
    class_weight=class_weights
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={'Normal Operation': np.float64(0.2931015301866836),
#                                      'Open Circuit': np.float64(56.585443037974684),
#                                      'Shadowing': np.float64(1.808509474131013),
#                                      'Short-Circuit': np.float64(56.82126484684309)},
#                        n_jobs=-1, random_state=42)

# %%
# Get predictions
y_pred = rf.predict(X_test)
y_proba = rf.predict_proba(X_test)

# %%
class_order = rf.classes_
print("Class order:", class_order)
# Out:
# Class order: ['Normal Operation' 'Open Circuit' 'Shadowing' 'Short-Circuit']

# %% [markdown]
# ## Model Evaluation
#
# The model is evaluated using:
#
# - Accuracy
# - Balanced Accuracy
# - Precision (Macro)
# - Recall (Macro)
# - F1-Score (Macro)
# - Cohen's Kappa
# - Log Loss
# - ROC-AUC (OvR)
# - PR-AUC

# %%
acc = accuracy_score(y_test, y_pred)
bacc = balanced_accuracy_score(y_test, y_pred)

# %%
prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
    y_test, y_pred, average="macro", zero_division=0
)

# %%
kappa = cohen_kappa_score(y_test, y_pred)

# Log Loss needs proba + true labels
ll = log_loss(y_test, y_proba, labels=class_order)

# For ROC-AUC + PR-AUC (macro), we need binarized y
y_test_bin = label_binarize(y_test, classes=class_order)

# %% [markdown]
# ### Cohen's Kappa Score
#
# Accuracy can be misleading when classes are imbalanced, because it does not account for the possibility of correct predictions occuring by chance. Cohen's Kappa measures the agreement between true and predicted labels while correcting for agreement that may occur by chance.
#
# Cohen’s Kappa is given by: $$\kappa = \frac{p_o - p_e}{1 - p_e}$$
#
# where:
#
# - $p_o$ = Observed agreement (accuracy)
# - $p_e$ = Expected agreement by chance

# %%
roc_auc_macro = roc_auc_score(y_test_bin, y_proba, average="macro", multi_class="ovr")
pr_auc_macro  = average_precision_score(y_test_bin, y_proba, average="macro")

# %%
metrics_dict = {
    "accuracy": float(acc),
    "balanced_accuracy": float(bacc),
    "precision_macro": float(prec_macro),
    "recall_macro": float(rec_macro),
    "f1_macro": float(f1_macro),
    "cohens_kappa": float(kappa),
    "log_loss": float(ll),
    "roc_auc_macro_ovr": float(roc_auc_macro),
    "pr_auc_macro": float(pr_auc_macro)
}

# %%
print("\nRandom Forest: Evaluation Metrics:")
for k, v in metrics_dict.items():
    print(f"{k:20s}: {v:.6f}")
# Out:
# Random Forest: Evaluation Metrics:
# accuracy            : 0.999168
# balanced_accuracy   : 0.997796
# precision_macro     : 0.998795
# recall_macro        : 0.997796
# f1_macro            : 0.998295
# cohens_kappa        : 0.996713
# log_loss            : 0.002485
# roc_auc_macro_ovr   : 0.999996
# pr_auc_macro        : 0.999977

# %%
# Visualize confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=class_order)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Reds")
plt.show()

# %%
# View classification report
print(classification_report(y_test, y_pred, target_names=class_order, digits=4))
# Out:
#                   precision    recall  f1-score   support
#
# Normal Operation     0.9995    0.9996    0.9995    232587
#     Open Circuit     1.0000    1.0000    1.0000      1205
#        Shadowing     0.9974    0.9966    0.9970     37694
#    Short-Circuit     0.9983    0.9950    0.9967      1200
#
#         accuracy                         0.9992    272686
#        macro avg     0.9988    0.9978    0.9983    272686
#     weighted avg     0.9992    0.9992    0.9992    272686

# %%
print(classification_report(y_test, y_pred, target_names=class_order))
# Out:
#                   precision    recall  f1-score   support
#
# Normal Operation       1.00      1.00      1.00    232587
#     Open Circuit       1.00      1.00      1.00      1205
#        Shadowing       1.00      1.00      1.00     37694
#    Short-Circuit       1.00      0.99      1.00      1200
#
#         accuracy                           1.00    272686
#        macro avg       1.00      1.00      1.00    272686
#     weighted avg       1.00      1.00      1.00    272686

# %%
def plot_roc_curves_macro(y_true_bin, y_proba, class_names, class_colors):
    plt.figure(figsize=(8, 6))

    for i, cls in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_proba[:, i])
        cls_auc = auc(fpr, tpr)

        color = class_colors.get(cls)
        plt.plot(fpr, tpr, label=f"{cls} (AUC={cls_auc:.3f})",
                 color=color)

    plt.plot([0, 1], [0, 1], linestyle="--", color="black")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curves (OvR - Macro Focus)")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
class_colors = {
"Normal Operation": "#2ca02c",
"Short-Circuit": "#d62728",
"Open Circuit": "#ff7f0e",
"Shadowing": "#1f77b4"
}

# %%
plot_roc_curves_macro(y_test_bin, y_proba, class_order, class_colors)

# %%
def plot_pr_curves_macro(y_true_bin, y_proba, class_names, class_colors):
    plt.figure(figsize=(8, 6))

    for i, cls in enumerate(class_names):
        p, r, _ = precision_recall_curve(y_true_bin[:, i], y_proba[:, i])
        ap = average_precision_score(y_true_bin[:, i], y_proba[:, i])

        color = class_colors.get(cls, None)

        plt.plot(
            r,
            p,
            label=f"{cls} (AP={ap:.3f})",
            color=color
        )

    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision–Recall Curves (OvR)")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_pr_curves_macro(y_test_bin, y_proba, class_order, class_colors)

# %%
def plot_metrics_barchart(metrics_dict, title="Model Metrics", include_log_loss=True):
    """
    Bar chart for key evaluation metrics.
    Note: log_loss is plotted separately because lower is better.
    """
    metric_keys = [
        "accuracy",
        "balanced_accuracy",
        "precision_macro",
        "recall_macro",
        "f1_macro",
        "cohens_kappa",
        "roc_auc_macro_ovr",
        "pr_auc_macro",
    ]

    
    plt.figure(figsize=(10, 5))
    plt.bar(metric_keys, [metrics_dict[k] for k in metric_keys])
    plt.xticks(rotation=45, ha="right")
    plt.ylabel("Score")
    plt.title(title)
    plt.tight_layout()
    plt.show()
    
    if include_log_loss and "log_loss" in metrics_dict:
        plt.figure(figsize=(5, 4))
        plt.bar(["log_loss"], [metrics_dict["log_loss"]])
        plt.ylabel("Log Loss (lower is better)")
        plt.title("Log Loss")
        plt.tight_layout()
        plt.show()

# %%
plot_metrics_barchart(metrics_dict)

# %% [markdown]
# ## Feature Importance Analysis
#
# Random Forest provides feature importance scores, indicating which electrical measurements contribute most to fault classification.

# %%
def plot_feature_importance_barchart(model, feature_names, top_n=10, title="Feature Importances"):
    """
    Bar chart for feature importances.
    """
    importances = model.feature_importances_
    fi = pd.DataFrame({"feature": feature_names, "importance": importances})
    fi = fi.sort_values("importance", ascending=False).head(top_n)

    plt.figure(figsize=(10, 6))
    plt.bar(fi["feature"], fi["importance"], color="green")
    plt.xticks(rotation=45, ha="right")
    plt.ylabel("Importance")
    plt.title(f"{title} (Top {top_n})")
    plt.tight_layout()
    plt.show()

    return fi

# %%
plot_feature_importance_barchart(rf, feature_names)
# Out:
#           feature  importance
# 8     total_power    0.198992
# 9   voltage_ratio    0.140963
# 4      irradiance    0.132089
# 6   power_string1    0.103867
# 3            idc2    0.084394
# 2            idc1    0.072119
# 1            vdc2    0.069418
# 7   power_string2    0.067384
# 10  current_ratio    0.053538
# 5     temperature    0.050533

# %%
def check_overfitting_underfitting(model, X, y):
    y_pred = model.predict(X)
    acc = accuracy_score(y, y_pred)
    return acc

# %%
train_acc_base = check_overfitting_underfitting(rf, X_train, y_train)
test_acc_base = check_overfitting_underfitting(rf, X_test, y_test)

# %%
print("Base RF")
print("Train Accuracy:", train_acc_base)
print("Test  Accuracy:", test_acc_base)
# Out:
# Base RF
# Train Accuracy: 1.0
# Test  Accuracy: 0.9991675406878241

# %% [markdown]
# ## Cross-Validation
#
# 3-fold Stratified Cross-Validation is used to estimate model stability and generelization performance.

# %%
# Stratified to preserve class distribution across folds
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# %%
# Scoring dictionary for metrics
scoring = {
    "accuracy": "accuracy",
    "balanced_accuracy": "balanced_accuracy",
    "precision_macro": "precision_macro",
    "recall_macro": "recall_macro",
    "f1_macro": "f1_macro",
    "roc_auc_ovr": "roc_auc_ovr"
}

# %%
cv_results = cross_validate(
    rf,
    X_train,
    y_train,
    cv=cv,
    scoring=scoring,
    n_jobs=-1,
    return_train_score=False
)

# %%
def plot_cv_results(cv_results, scoring_dict):
    means = []
    stds = []
    labels = []

    for metric in scoring_dict.keys():
        scores = cv_results[f"test_{metric}"]
        means.append(scores.mean())
        stds.append(scores.std())
        labels.append(metric)

    plt.figure(figsize=(10, 5))
    plt.bar(labels, means, yerr=stds, capsize=5)
    plt.xticks(rotation=45, ha="right")
    plt.ylabel("Score")
    plt.title("3-Fold Cross Validation (Mean ± Std)")
    plt.tight_layout()
    plt.show()

# %%
plot_cv_results(cv_results, scoring)

# %%
param_dist = {
    "n_estimators": [100, 150, 200, 250, 400, 500, 600],
    "max_depth": [None, 10, 20, 25, 35, 40],
    "min_samples_split": [2, 3, 4, 5, 6, 7, 8, 9],
    "min_samples_leaf": [1, 2, 3, 4, 5],
    "max_features": ["sqrt", "log2", 0.5, None]
}

# %%
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# %%
base_rf = RandomForestClassifier(class_weight=class_weights,
                                 n_jobs=-1, random_state=42)

# %% [markdown]
# ## Hyperparameter Tuning
#
# Randomized Search is used to optimize key Random Forest hyperparameters including:
#
# - Number of trees
# - Maximum depth
# - Minimum samples per split
# - Minimum samples per leaf
# - Maximum features

# %%
random_search = RandomizedSearchCV(
    estimator=base_rf,
    param_distributions=param_dist,
    n_iter=15,
    cv=cv,
    scoring="roc_auc_ovr",
    n_jobs=-1,
    random_state=42,
    verbose=1,
    refit=True  # Best model is trained automatically
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                    estimator=RandomForestClassifier(class_weight={'Normal Operation': np.float64(0.2931015301866836),
#                                                                   'Open Circuit': np.float64(56.585443037974684),
#                                                                   'Shadowing': np.float64(1.808509474131013),
#                                                                   'Short-Circuit': np.float64(56.82126484684309)},
#                                                     n_jobs=-1,
#                                                     random_state=42),
#                    n_iter=15, n_jobs=-1,
#                    param_distributions={'max_depth': [None, 10, 20, 25, 35, 40],
#                                         'max_features': ['sqrt', 'log2', 0.5,
#                                                          None],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'min_samples_split': [2, 3, 4, 5, 6, 7,
#                                                               8, 9],
#                                         'n_estimators': [100, 150, 200, 250,
#                                                          400, 500, 600]},
#                    random_state=42, scoring='roc_auc_ovr', verbose=1)

# %%
print("Best hyperparameters:")
random_search.best_params_
# Out:
# Best hyperparameters:
# {'n_estimators': 400,
#  'min_samples_split': 7,
#  'min_samples_leaf': 3,
#  'max_features': 0.5,
#  'max_depth': 35}

# %%
# Best score
print("Best score:", random_search.best_score_)
# Out:
# Best score: 0.9999967934929982

# %% [markdown]
# ## Best Model Evaluation
#
# The same metrics were then applied to this tuned Random Forest to evaluate its performance.

# %%
best_rf = random_search.best_estimator_
y_pred_best = best_rf.predict(X_test)
y_proba_best = best_rf.predict_proba(X_test)

# %%
acc_best = accuracy_score(y_test, y_pred_best)
bacc_best = balanced_accuracy_score(y_test, y_pred_best)

# %%
prec_macro_best, rec_macro_best, f1_macro_best, _ = precision_recall_fscore_support(
    y_test, y_pred_best, average="macro", zero_division=0
)
kappa_best = cohen_kappa_score(y_test, y_pred_best)

# %%
best_class_order = best_rf.classes_

# %%
ll_best = log_loss(y_test, y_proba_best, labels=best_class_order)

# %%
y_test_bin_best = label_binarize(y_test, classes=best_class_order)
roc_auc_macro_best = roc_auc_score(y_test_bin_best, y_proba_best, average="macro", multi_class="ovr")
pr_auc_macro_best  = average_precision_score(y_test_bin_best, y_proba_best, average="macro")

# %%
best_metrics_dict = {
    "accuracy": float(acc_best),
    "balanced_accuracy": float(bacc_best),
    "precision_macro": float(prec_macro_best),
    "recall_macro": float(rec_macro_best),
    "f1_macro": float(f1_macro_best),
    "cohens_kappa": float(kappa_best),
    "log_loss": float(ll_best),
    "roc_auc_macro_ovr": float(roc_auc_macro_best),
    "pr_auc_macro": float(pr_auc_macro_best)
}

# %%
print("\nTuned Random Forest: Evaluation Metrics:")
for k, v in best_metrics_dict.items():
    print(f"{k:20s}: {v:.6f}")
# Out:
# Tuned Random Forest: Evaluation Metrics:
# accuracy            : 0.999124
# balanced_accuracy   : 0.998851
# precision_macro     : 0.997245
# recall_macro        : 0.998851
# f1_macro            : 0.998046
# cohens_kappa        : 0.996543
# log_loss            : 0.002511
# roc_auc_macro_ovr   : 0.999997
# pr_auc_macro        : 0.999982

# %%
# Visualize confusion matrix
cm = confusion_matrix(y_test, y_pred_best, labels=best_class_order)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Reds")
plt.title("Confusion Matrix of Tuned Random Forest", fontsize=16, fontweight='bold')
plt.show()

# %%
print(classification_report(y_test, y_pred_best, target_names=best_class_order, digits=4))
# Out:
#                   precision    recall  f1-score   support
#
# Normal Operation     0.9997    0.9994    0.9995    232587
#     Open Circuit     1.0000    1.0000    1.0000      1205
#        Shadowing     0.9959    0.9977    0.9968     37694
#    Short-Circuit     0.9934    0.9983    0.9958      1200
#
#         accuracy                         0.9991    272686
#        macro avg     0.9972    0.9989    0.9980    272686
#     weighted avg     0.9991    0.9991    0.9991    272686

# %%
print(classification_report(y_test, y_pred_best, target_names=best_class_order))
# Out:
#                   precision    recall  f1-score   support
#
# Normal Operation       1.00      1.00      1.00    232587
#     Open Circuit       1.00      1.00      1.00      1205
#        Shadowing       1.00      1.00      1.00     37694
#    Short-Circuit       0.99      1.00      1.00      1200
#
#         accuracy                           1.00    272686
#        macro avg       1.00      1.00      1.00    272686
#     weighted avg       1.00      1.00      1.00    272686

# %%
plot_roc_curves_macro(y_test_bin_best, y_proba_best, best_class_order, class_colors)

# %%
plot_pr_curves_macro(y_test_bin_best, y_proba_best, best_class_order, class_colors)

# %%
plot_metrics_barchart(best_metrics_dict)

# %%
plot_feature_importance_barchart(best_rf, feature_names)
# Out:
#           feature  importance
# 8     total_power    0.233978
# 4      irradiance    0.219726
# 6   power_string1    0.121166
# 9   voltage_ratio    0.111449
# 1            vdc2    0.085418
# 7   power_string2    0.053093
# 5     temperature    0.038744
# 3            idc2    0.038417
# 10  current_ratio    0.037593
# 0            vdc1    0.032164

# %% [markdown]
# ## Base vs Tuned Comparison
#
# The tuned model is compared against the base Random Forest to evaluate performance improvements across all metrics.

# %%
def make_comparison_with_change(base_metrics, tuned_metrics, round_dp=4):
    metric_order = [
        "accuracy",
        "balanced_accuracy",
        "precision_macro",
        "recall_macro",
        "f1_macro",
        "roc_auc_macro_ovr",
        "pr_auc_macro",
        "cohens_kappa",
        "log_loss",
    ]

    base = pd.Series(base_metrics, name="Base RF")[metric_order]
    tuned = pd.Series(tuned_metrics, name="Tuned RF")[metric_order]

    df = pd.concat([base, tuned], axis=1)

    df["Δ (Tuned-Base)"] = df["Tuned RF"] - df["Base RF"]
    df["% change"] = np.where(
        df["Base RF"] != 0,
        (df["Δ (Tuned-Base)"] / df["Base RF"]) * 100,
        np.nan
    )

    return df.round(round_dp)


compare_df = make_comparison_with_change(metrics_dict, best_metrics_dict, round_dp=6)
display(compare_df)
# Out:
#                     Base RF  Tuned RF  Δ (Tuned-Base)  % change
# accuracy           0.999168  0.999124       -0.000044 -0.004404
# balanced_accuracy  0.997796  0.998851        0.001055  0.105744
# precision_macro    0.998795  0.997245       -0.001550 -0.155201
# recall_macro       0.997796  0.998851        0.001055  0.105744
# f1_macro           0.998295  0.998046       -0.000249 -0.024895
# roc_auc_macro_ovr  0.999996  0.999997        0.000001  0.000114
# pr_auc_macro       0.999977  0.999982        0.000005  0.000534
# cohens_kappa       0.996713  0.996543       -0.000170 -0.017040
# log_loss           0.002485  0.002511        0.000026  1.063966

# %%
# Tuned RF
train_acc_best = check_overfitting_underfitting(best_rf, X_train, y_train)
test_acc_best  = check_overfitting_underfitting(best_rf, X_test, y_test)

print("\nTuned RF")
print("Train Accuracy:", train_acc_best)
print("Test  Accuracy:", test_acc_best)
# Out:
# Tuned RF
# Train Accuracy: 0.9997515450505665
# Test  Accuracy: 0.9991235340281496

# %% [markdown]
# ## Model Persistence
#
# The trained models, feature names, and class order are saved using joblib for integration and reproducability.

# %%
# Create folder to save models
os.makedirs("saved_models", exist_ok=True)

# %%
# Save models
joblib.dump(rf, "saved_models/base_random_forest.pkl")
joblib.dump(best_rf, "saved_models/tuned_random_forest.pkl")

# Save feature names
joblib.dump(feature_names, "saved_models/feature_names.pkl")

# Save class order
joblib.dump(best_rf.classes_, "saved_models/class_order.pkl")
print("Models saved successfuly.")
# Out:
# Models saved successfuly.
